# %%
import pandas as pd

# %%
# !pip install pandas

# %%
data=pd.read_csv('Salary Dataset.csv')
data.head(100)
# Out:
#                  Company Name       Job Title  Salaries Reported   Location  \
# 0                    Mu Sigma  Data Scientist              105.0  Bangalore
# 1                         IBM  Data Scientist               95.0  Bangalore
# 2   Tata Consultancy Services  Data Scientist               66.0  Bangalore
# 3            Impact Analytics  Data Scientist               40.0  Bangalore
# 4                   Accenture  Data Scientist               32.0  Bangalore
# ..                        ...             ...                ...        ...
# 95                        IBM  Data Scientist                4.0  Bangalore
# 96                     ascena  Data Scientist                4.0  Bangalore
# 97                   QuantZig  Data Scientist                4.0  Bangalore
# 98               Baker Hughes  Data Scientist                4.0  Bangalore
# 99                 Everlytics  Data Scientist                4.0  Bangalore
#
#            Salary
# 0    ₹6,48,573/yr
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4344 entries, 0 to 4343
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company Name       4341 non-null   object
#  1   Job Title          4344 non-null   object
#  2   Salaries Reported  4342 non-null   float64
#  3   Location           4344 non-null   object
#  4   Salary             4344 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 169.8+ KB

# %%
data['Salary']=data['Salary'].str[1:]

# %%
data['Salary']=data['Salary'].str.replace('/yr','')

# %%
data['Salary']=data['Salary'].str.replace(',','')

# %%
data['Salary']=data['Salary'].str.replace('/mo','')
data['Salary']=data['Salary'].str.replace('/hr','')

# %%
data['Salary']
# Out:
# 0        648573
# 1       1191950
# 2        836874
# 3        669578
# 4        944110
#          ...
# 4339       5180
# 4340     751286
# 4341     410952
# 4342    1612324
# 4343     939843
# Name: Salary, Length: 4344, dtype: object

# %%
data['new_Location']=data['Location']+'new'

# %%
data
# Out:
#                    Company Name                             Job Title  \
# 0                      Mu Sigma                        Data Scientist
# 1                           IBM                        Data Scientist
# 2     Tata Consultancy Services                        Data Scientist
# 3              Impact Analytics                        Data Scientist
# 4                     Accenture                        Data Scientist
# ...                         ...                                   ...
# 4339                    TaiyōAI            Machine Learning Scientist
# 4340    Decimal Point Analytics            Machine Learning Developer
# 4341                     MyWays            Machine Learning Developer
# 4342  Market Pulse Technologies  Software Engineer - Machine Learning
# 4343                    vPhrase             Machine Learning Engineer
#
#       Salaries Reported   Location   Salary  new_Location
# 0                 105.0  Bangalore   648573  Bangalorenew
# ...

# %%
def salary(x):
    
    
    if 'm' in x:
        x=x[:-3]
        x=int(x)
        return x*12
    elif 'h' in x:
        x=x[:-3]
        x=int(x)
        return x*24*30*12
        
    else:
        x=int(x)
        return x

# %%
data
# Out:
#                    Company Name                             Job Title  \
# 0                      Mu Sigma                        Data Scientist
# 1                           IBM                        Data Scientist
# 2     Tata Consultancy Services                        Data Scientist
# 3              Impact Analytics                        Data Scientist
# 4                     Accenture                        Data Scientist
# ...                         ...                                   ...
# 4339                    TaiyōAI            Machine Learning Scientist
# 4340    Decimal Point Analytics            Machine Learning Developer
# 4341                     MyWays            Machine Learning Developer
# 4342  Market Pulse Technologies  Software Engineer - Machine Learning
# 4343                    vPhrase             Machine Learning Engineer
#
#       Salaries Reported   Location   Salary
# 0                 105.0  Bangalore   648573
# ...

# %%
data.to_csv('Updated_company_file')

# %%
x=str(7)
y=x*12
print(y)

# %%
data1=pd.read_csv(Updated_company_file')
                  data
